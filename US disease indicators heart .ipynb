# %%
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('U.S._Chronic_Disease_Indicators__CDI_.csv')

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2015     2015           US         United States       APIS  Alcohol
# 1       2012     2012           DC  District of Columbia       APIS  Alcohol
# 2       2012     2012           GU                  Guam       APIS  Alcohol
# 3       2012     2012           PR           Puerto Rico       APIS  Alcohol
# 4       2012     2012           US         United States       APIS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Amount of alcohol excise tax by beverage type ...      NaN             $
# 1  Amount of alcohol excise tax by beverage type ...      NaN             $
# 2  Amount of alcohol excise tax by beverage type ...      NaN             $
# 3  Amount of alcohol excise tax by beverage type ...      NaN             $
# 4  Amount of alcohol excise tax by beverage type ...      NaN             $
#
# ...

# %%
df.tail()
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc            DataSource  \
# 519713       2014     2014           DE     Delaware                 BRFSS
# 519714       2015     2015           OR       Oregon                 BRFSS
# 519715       2014     2014           AR     Arkansas  State Inpatient Data
# 519716       2016     2016           CT  Connecticut                 BRFSS
# 519717       2013     2013           TX        Texas                 BRFSS
#
#                                                   Topic  \
# 519713                                        Arthritis
# 519714  Nutrition, Physical Activity, and Weight Status
# 519715            Chronic Obstructive Pulmonary Disease
# 519716                           Cardiovascular Disease
# 519717  Nutrition, Physical Activity, and Weight Status
#
#                                                  Question Response  \
# 519713  Physical inactivity among adults aged >= 18 ye...      NaN
# ...

# %%
df.shape
# Out:
# (519718, 34)

# %%
df.YearEnd.value_counts()
# Out:
# 2014    97815
# 2013    94268
# 2012    82598
# 2011    82566
# 2015    72327
# 2016    60266
# 2010    29611
# 2008      108
# 2001      104
# 2007       55
# Name: YearEnd, dtype: int64

# %%
df.Topic.unique()
# Out:
# array(['Alcohol', 'Nutrition, Physical Activity, and Weight Status',
#        'Cardiovascular Disease', 'Arthritis', 'Diabetes', 'Tobacco',
#        'Overarching Conditions', 'Chronic Obstructive Pulmonary Disease',
#        'Cancer', 'Chronic Kidney Disease', 'Asthma', 'Disability',
#        'Oral Health', 'Older Adults', 'Mental Health', 'Immunization',
#        'Reproductive Health'], dtype=object)

# %%
df.Topic.value_counts().plot(kind='bar')
plt.title('Chronic Diseases',fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('Chronic disease')

# %%
 df.Question.unique()
# Out:
# array(['Amount of alcohol excise tax by beverage type (wine)',
#        'Amount of alcohol excise tax by beverage type (beer)',
#        'Amount of alcohol excise tax by beverage type (distilled spirits)',
#        'Obesity among adults aged >= 18 years',
#        'Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years',
#        'Binge drinking frequency among adults aged >= 18 years who binge drink',
#        'Arthritis among adults aged >= 18 years who have diabetes',
#        'Foot examination among adults aged >= 18 years with diagnosed diabetes',
#        'Current smoking among adults aged >= 18 years',
#        'Chronic liver disease mortality', 'Mortality from heart failure',
#        'Heavy drinking among adults aged >= 18 years',
#        'Quit attempts in the past year among current smokers',
#        'Prevalence of sufficient sleep among adults aged >= 18 years',
#        'Hospitalization for acute myocardial infarction', 'Poverty',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519718 entries, 0 to 519717
# Data columns (total 34 columns):
# YearStart                    519718 non-null int64
# YearEnd                      519718 non-null int64
# LocationAbbr                 519718 non-null object
# LocationDesc                 519718 non-null object
# DataSource                   519718 non-null object
# Topic                        519718 non-null object
# Question                     519718 non-null object
# Response                     79188 non-null object
# DataValueUnit                476046 non-null object
# DataValueType                519718 non-null object
# DataValue                    374564 non-null object
# DataValueAlt                 350335 non-null float64
# DataValueFootnoteSymbol      227318 non-null object
# DatavalueFootnote            227152 non-null object
# LowConfidenceLimit           311062 non-null float64
# HighConfidenceLimit          311062 non-null float64
# ...

# %%
df1 = df.groupby(['Topic', 'Question']).size().reset_index(name = 'freq')
df1
# Out:
#                       Topic  \
# 0                   Alcohol
# 1                   Alcohol
# 2                   Alcohol
# 3                   Alcohol
# 4                   Alcohol
# 5                   Alcohol
# 6                   Alcohol
# 7                   Alcohol
# 8                   Alcohol
# 9                   Alcohol
# 10                  Alcohol
# 11                  Alcohol
# 12                  Alcohol
# 13                  Alcohol
# 14                  Alcohol
# 15                  Alcohol
# 16                Arthritis
# 17                Arthritis
# 18                Arthritis
# 19                Arthritis
# 20                Arthritis
# 21                Arthritis
# 22                Arthritis
# 23                Arthritis
# 24                Arthritis
# 25                Arthritis
# 26                   Asthma
# 27                   Asthma
# 28                   Asthma
# 29                   Asthma
# ..                      ...
# 173  Overarching Conditions
# ...

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
df.Stratification1.unique()
# Out:
# array(['Overall', 'Multiracial, non-Hispanic', 'Black, non-Hispanic',
#        'Female', 'White, non-Hispanic', 'Male',
#        'American Indian or Alaska Native', 'Hispanic',
#        'Other, non-Hispanic', 'Asian or Pacific Islander',
#        'Asian, non-Hispanic'], dtype=object)

# %%
df.StratificationCategory1.unique()
# Out:
# array(['Overall', 'Race/Ethnicity', 'Gender'], dtype=object)

# %%
##to check is there any value in this column
df.Stratification2.unique()
# Out:
# array([nan, ' '], dtype=object)

# %%
df.StratificationCategory2.unique()
# Out:
# array([nan, ' '], dtype=object)

# %%
df.StratificationCategoryID3.unique()
# Out:
# array([nan, ' '], dtype=object)

# %%
df.StratificationID3.unique()
# Out:
# array([nan, ' '], dtype=object)

# %%
df.GeoLocation
# Out:
# 0                                       NaN
# 1                   (38.907192, -77.036871)
# 2                   (13.444304, 144.793731)
# 3                   (18.220833, -66.590149)
# 4                                       NaN
# 5                   (18.335765, -64.896335)
# 6                   (13.444304, 144.793731)
# 7                   (18.220833, -66.590149)
# 8                                       NaN
# 9                   (18.335765, -64.896335)
# 10                  (13.444304, 144.793731)
# 11                  (18.220833, -66.590149)
# 12                                      NaN
# 13                  (18.335765, -64.896335)
# 14                  (38.907192, -77.036871)
# 15                                      NaN
# 16                                      NaN
# 17           (44.567449424, -120.155031326)
# 18           (47.066528972, -109.424420645)
# 19           (43.235541343, -108.109830353)
# 20           (43.235541343, -108.109830353)
# ...

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
df.drop(['StratificationCategoryID2', 'StratificationID2','StratificationCategoryID3','StratificationID3'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
df.StratificationID1.unique()
# Out:
# array(['OVR', 'MRC', 'BLK', 'GENF', 'WHT', 'GENM', 'AIAN', 'HIS', 'OTH',
#        'API', 'ASN'], dtype=object)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2015     2015           US         United States       APIS  Alcohol
# 1       2012     2012           DC  District of Columbia       APIS  Alcohol
# 2       2012     2012           GU                  Guam       APIS  Alcohol
# 3       2012     2012           PR           Puerto Rico       APIS  Alcohol
# 4       2012     2012           US         United States       APIS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Amount of alcohol excise tax by beverage type ...      NaN             $
# 1  Amount of alcohol excise tax by beverage type ...      NaN             $
# 2  Amount of alcohol excise tax by beverage type ...      NaN             $
# 3  Amount of alcohol excise tax by beverage type ...      NaN             $
# 4  Amount of alcohol excise tax by beverage type ...      NaN             $
#
# ...

# %%
df.LowConfidenceLimit.unique()
# Out:
# array([   nan,  13.3 ,  36.88, ...,  80.85,  88.09, 238.03])

# %%
df.GeoLocation
# Out:
# 0                                       NaN
# 1                   (38.907192, -77.036871)
# 2                   (13.444304, 144.793731)
# 3                   (18.220833, -66.590149)
# 4                                       NaN
# 5                   (18.335765, -64.896335)
# 6                   (13.444304, 144.793731)
# 7                   (18.220833, -66.590149)
# 8                                       NaN
# 9                   (18.335765, -64.896335)
# 10                  (13.444304, 144.793731)
# 11                  (18.220833, -66.590149)
# 12                                      NaN
# 13                  (18.335765, -64.896335)
# 14                  (38.907192, -77.036871)
# 15                                      NaN
# 16                                      NaN
# 17           (44.567449424, -120.155031326)
# 18           (47.066528972, -109.424420645)
# 19           (43.235541343, -108.109830353)
# 20           (43.235541343, -108.109830353)
# ...

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2015     2015           US         United States       APIS  Alcohol
# 1       2012     2012           DC  District of Columbia       APIS  Alcohol
# 2       2012     2012           GU                  Guam       APIS  Alcohol
# 3       2012     2012           PR           Puerto Rico       APIS  Alcohol
# 4       2012     2012           US         United States       APIS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Amount of alcohol excise tax by beverage type ...      NaN             $
# 1  Amount of alcohol excise tax by beverage type ...      NaN             $
# 2  Amount of alcohol excise tax by beverage type ...      NaN             $
# 3  Amount of alcohol excise tax by beverage type ...      NaN             $
# 4  Amount of alcohol excise tax by beverage type ...      NaN             $
#
# ...

# %%
lat = []
lng = []

for row in df['GeoLocation']:
    try:
        lat.append(row.split(',')[0])
        lng.append(row.split(',')[1])
    except:
        lat.append(np.NaN)
        lng.append(np.NaN)
        
df['Latitute'] = lat
df['longitude'] = lng

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2015     2015           US         United States       APIS  Alcohol
# 1       2012     2012           DC  District of Columbia       APIS  Alcohol
# 2       2012     2012           GU                  Guam       APIS  Alcohol
# 3       2012     2012           PR           Puerto Rico       APIS  Alcohol
# 4       2012     2012           US         United States       APIS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Amount of alcohol excise tax by beverage type ...      NaN             $
# 1  Amount of alcohol excise tax by beverage type ...      NaN             $
# 2  Amount of alcohol excise tax by beverage type ...      NaN             $
# 3  Amount of alcohol excise tax by beverage type ...      NaN             $
# 4  Amount of alcohol excise tax by beverage type ...      NaN             $
#
# ...

# %%
df['GeoLocation'] = df['GeoLocation'].replace(to_replace='\(', value="", regex=True)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2015     2015           US         United States       APIS  Alcohol
# 1       2012     2012           DC  District of Columbia       APIS  Alcohol
# 2       2012     2012           GU                  Guam       APIS  Alcohol
# 3       2012     2012           PR           Puerto Rico       APIS  Alcohol
# 4       2012     2012           US         United States       APIS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Amount of alcohol excise tax by beverage type ...      NaN             $
# 1  Amount of alcohol excise tax by beverage type ...      NaN             $
# 2  Amount of alcohol excise tax by beverage type ...      NaN             $
# 3  Amount of alcohol excise tax by beverage type ...      NaN             $
# 4  Amount of alcohol excise tax by beverage type ...      NaN             $
#
# ...

# %%
df.GeoLocation
# Out:
# 0                                      NaN
# 1                   38.907192, -77.036871)
# 2                   13.444304, 144.793731)
# 3                   18.220833, -66.590149)
# 4                                      NaN
# 5                   18.335765, -64.896335)
# 6                   13.444304, 144.793731)
# 7                   18.220833, -66.590149)
# 8                                      NaN
# 9                   18.335765, -64.896335)
# 10                  13.444304, 144.793731)
# 11                  18.220833, -66.590149)
# 12                                     NaN
# 13                  18.335765, -64.896335)
# 14                  38.907192, -77.036871)
# 15                                     NaN
# 16                                     NaN
# 17           44.567449424, -120.155031326)
# 18           47.066528972, -109.424420645)
# 19           43.235541343, -108.109830353)
# 20           43.235541343, -108.109830353)
# 21         41.641040988001, -99.365720623)
# ...

# %%
df['GeoLocation'] = df['GeoLocation'].replace(to_replace='\(|\)', value="", regex=True)

# %%
df.GeoLocation
# Out:
# 0                                     NaN
# 1                   38.907192, -77.036871
# 2                   13.444304, 144.793731
# 3                   18.220833, -66.590149
# 4                                     NaN
# 5                   18.335765, -64.896335
# 6                   13.444304, 144.793731
# 7                   18.220833, -66.590149
# 8                                     NaN
# 9                   18.335765, -64.896335
# 10                  13.444304, 144.793731
# 11                  18.220833, -66.590149
# 12                                    NaN
# 13                  18.335765, -64.896335
# 14                  38.907192, -77.036871
# 15                                    NaN
# 16                                    NaN
# 17           44.567449424, -120.155031326
# 18           47.066528972, -109.424420645
# 19           43.235541343, -108.109830353
# 20           43.235541343, -108.109830353
# 21         41.641040988001, -99.365720623
# ...

# %%
df['GeoLocation'] = df['GeoLocation'].replace(to_replace='\(|\)', value="", regex=True)

# %%
df.GeoLocation
# Out:
# 0                                     NaN
# 1                   38.907192, -77.036871
# 2                   13.444304, 144.793731
# 3                   18.220833, -66.590149
# 4                                     NaN
# 5                   18.335765, -64.896335
# 6                   13.444304, 144.793731
# 7                   18.220833, -66.590149
# 8                                     NaN
# 9                   18.335765, -64.896335
# 10                  13.444304, 144.793731
# 11                  18.220833, -66.590149
# 12                                    NaN
# 13                  18.335765, -64.896335
# 14                  38.907192, -77.036871
# 15                                    NaN
# 16                                    NaN
# 17           44.567449424, -120.155031326
# 18           47.066528972, -109.424420645
# 19           43.235541343, -108.109830353
# 20           43.235541343, -108.109830353
# 21         41.641040988001, -99.365720623
# ...

# %%
df.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# Response                      object
# DataValueUnit                 object
# DataValueType                 object
# DataValue                     object
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2       object
# Stratification2               object
# StratificationCategory3       object
# Stratification3               object
# GeoLocation                   object
# ResponseID                    object
# LocationID                     int64
# ...

# %%
df_new = df[['Topic','Question']]

# %%
df_new
# Out:
#                                                   Topic  \
# 0                                               Alcohol
# 1                                               Alcohol
# 2                                               Alcohol
# 3                                               Alcohol
# 4                                               Alcohol
# 5                                               Alcohol
# 6                                               Alcohol
# 7                                               Alcohol
# 8                                               Alcohol
# 9                                               Alcohol
# 10                                              Alcohol
# 11                                              Alcohol
# 12                                              Alcohol
# 13                                              Alcohol
# 14                                              Alcohol
# 15                                              Alcohol
# ...

# %%
df_new.keys()
# Out:
# Index(['Topic', 'Question'], dtype='object')

# %%
df_dict = dict(zip(df_new.Question, df_new.Topic))

# %%
df_dict
# Out:
# {'Amount of alcohol excise tax by beverage type (wine)': 'Alcohol',
#  'Amount of alcohol excise tax by beverage type (beer)': 'Alcohol',
#  'Amount of alcohol excise tax by beverage type (distilled spirits)': 'Alcohol',
#  'Obesity among adults aged >= 18 years': 'Nutrition, Physical Activity, and Weight Status',
#  'Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years': 'Cardiovascular Disease',
#  'Binge drinking frequency among adults aged >= 18 years who binge drink': 'Alcohol',
#  'Arthritis among adults aged >= 18 years who have diabetes': 'Arthritis',
#  'Foot examination among adults aged >= 18 years with diagnosed diabetes': 'Diabetes',
#  'Current smoking among adults aged >= 18 years': 'Tobacco',
#  'Chronic liver disease mortality': 'Alcohol',
#  'Mortality from heart failure': 'Cardiovascular Disease',
#  'Heavy drinking among adults aged >= 18 years': 'Alcohol',
#  'Quit attempts in the past year among current smokers': 'Tobacco',
# ...

# %%
from collections import Counter

# %%
for keys, value in df_dict.items():
    print(keys,value)
# Out:
# Amount of alcohol excise tax by beverage type (wine) Alcohol
# Amount of alcohol excise tax by beverage type (beer) Alcohol
# Amount of alcohol excise tax by beverage type (distilled spirits) Alcohol
# Obesity among adults aged >= 18 years Nutrition, Physical Activity, and Weight Status
# Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years Cardiovascular Disease
# Binge drinking frequency among adults aged >= 18 years who binge drink Alcohol
# Arthritis among adults aged >= 18 years who have diabetes Arthritis
# Foot examination among adults aged >= 18 years with diagnosed diabetes Diabetes
# Current smoking among adults aged >= 18 years Tobacco
# Chronic liver disease mortality Alcohol
# Mortality from heart failure Cardiovascular Disease
# Heavy drinking among adults aged >= 18 years Alcohol
# Quit attempts in the past year among current smokers Tobacco
# Prevalence of sufficient sleep among adults aged >= 18 years Overarching Conditions
# ...

# %%
count = 0
    for keys, value in df_dict.items(): 
        count += len(value) 
    print(count)
# Out:
#   File "<ipython-input-44-ccd0f711f94d>", line 2
#     for keys, value in df_dict.items():
#     ^
# IndentationError: unexpected indent

# %%
for keys, values in df_dict.items():
    if keys in df_dict.keys():
        df_dict(keys) += 1
    else:
        df_dict(keys) = 1
# Out:
#   File "<ipython-input-51-ca200c41735c>", line 3
#     df_dict(keys) += 1
#     ^
# SyntaxError: can't assign to function call

# %%
for keys, values in df_dict.items():
         print(keys,value)
# Out:
# Amount of alcohol excise tax by beverage type (wine) Overarching Conditions
# Amount of alcohol excise tax by beverage type (beer) Overarching Conditions
# Amount of alcohol excise tax by beverage type (distilled spirits) Overarching Conditions
# Obesity among adults aged >= 18 years Overarching Conditions
# Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years Overarching Conditions
# Binge drinking frequency among adults aged >= 18 years who binge drink Overarching Conditions
# Arthritis among adults aged >= 18 years who have diabetes Overarching Conditions
# Foot examination among adults aged >= 18 years with diagnosed diabetes Overarching Conditions
# Current smoking among adults aged >= 18 years Overarching Conditions
# Chronic liver disease mortality Overarching Conditions
# Mortality from heart failure Overarching Conditions
# Heavy drinking among adults aged >= 18 years Overarching Conditions
# ...

# %%
count = 0
count = 0
    for x in enumerate(d.items()): 
  
        # enumerate function returns a tuple in the form 
        # (index, (key, value)) it is a nested tuple 
        # for accessing the value we do indexing x[1][1] 
        if isinstance(x[1][1], list): 
            count += len(x[1][1]) 
    print(count) 
    for x in enumerate(df_dict.items()): 
        if isinstance(x[1][1], list): 
            count += len(x[1][1]) 
    print(count)
# Out:
#   File "<ipython-input-53-26f3f3a729b3>", line 3
#     for x in enumerate(d.items()):
#     ^
# IndentationError: unexpected indent

# %%
count = 0

    for x in enumerate(df_dict.items()): 
  
        # enumerate function returns a tuple in the form 
        # (index, (key, value)) it is a nested tuple 
        # for accessing the value we do indexing x[1][1] 
        if isinstance(x[1][1], list): 
            count += len(x[1][1]) 
    print(count)
# Out:
#   File "<ipython-input-54-fb397b7144f3>", line 3
#     for x in enumerate(df_dict.items()):
#     ^
# IndentationError: unexpected indent

# %%
count ={}

for keys in df_dict.items():
        count[keys]
        print(count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-ebb4a1bb5471> in <module>
#       2
#       3 for keys in df_dict.items():
# ----> 4         count[keys]
#       5         print(count)
#
# KeyError: ('Amount of alcohol excise tax by beverage type (wine)', 'Alcohol')

# %%
list1 = df_new['Topic'].to_list()

# %%
list2 = df_new['Question'].to_list()

# %%
list3 = list1 + list2

# %%
list2
# Out:
# ['Amount of alcohol excise tax by beverage type (wine)',
#  'Amount of alcohol excise tax by beverage type (beer)',
#  'Amount of alcohol excise tax by beverage type (beer)',
#  'Amount of alcohol excise tax by beverage type (beer)',
#  'Amount of alcohol excise tax by beverage type (beer)',
#  'Amount of alcohol excise tax by beverage type (beer)',
#  'Amount of alcohol excise tax by beverage type (wine)',
#  'Amount of alcohol excise tax by beverage type (wine)',
#  'Amount of alcohol excise tax by beverage type (wine)',
#  'Amount of alcohol excise tax by beverage type (wine)',
#  'Amount of alcohol excise tax by beverage type (distilled spirits)',
#  'Amount of alcohol excise tax by beverage type (distilled spirits)',
#  'Amount of alcohol excise tax by beverage type (distilled spirits)',
#  'Amount of alcohol excise tax by beverage type (distilled spirits)',
#  'Amount of alcohol excise tax by beverage type (beer)',
# ...

# %%
c = print (Counter(list2))
print(c)
# Out:
# Counter({'Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years': 7488, 'Hospitalization for chronic obstructive pulmonary disease as any diagnosis among Medicare-eligible persons aged >= 65 years': 7488, 'Hospitalization for chronic obstructive pulmonary disease as first-listed diagnosis among Medicare-eligible persons aged >= 65 years': 7488, 'Hospitalization for hip fracture among Medicare-eligible persons aged >= 65 years': 7488, 'Chronic liver disease mortality': 6135, 'Mortality from heart failure': 6135, 'Mortality with end-stage renal disease': 6135, 'Mortality due to diabetes reported as any listed cause of death': 6135, 'Mortality from total cardiovascular diseases': 6135, 'Mortality with chronic obstructive pulmonary disease as underlying or contributing cause among adults aged >= 45 years': 6135, 'Premature mortality among adults aged 45-64 years': 6135, 'Mortality with diabetic ketoacidosis reported as any listed cause of death': 6135, 'Asthm
# ...

# %%
dict((i,list2.count(i)) for i in list2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-1d24da76c318> in <module>
# ----> 1 dict((i,list2.count(i)) for i in list2)
#
# <ipython-input-61-1d24da76c318> in <genexpr>(.0)
# ----> 1 dict((i,list2.count(i)) for i in list2)
#
# KeyboardInterrupt:

# %%
Counter(list2).keys()

# %%
df3 = df[(df['Question'] == 'Mortality from heart failure')]

# %%
df3

# %%
df3 = df3[['YearStart','LocationDesc','Topic','Question','DataValueUnit','DataValue','DataValueAlt','Stratification1','Latitute','longitude']]

# %%
df3

# %%
df3.dtypes

# %%
df3['DataValue'] = df3['DataValue'].replace(" ", "", regex=True)
df3['DataValue'].replace("", np.nan, inplace=True) # replace empty string with np.nan
df3['DataValue'].dropna(inplace=True) # drop nan values
int_series = df3['DataValue'].astype(float) # change type

calculated_series = int_series.apply(lambda x: x*(1/1.2))

print(calculated_series)

# %%
 df3['DataValue'].astype(float)

# %%
df_heart.pivot_table(values =['YearStart'], index =['LocationDesc', 'Stratification1','DataValueUnit'], 
                         columns =['Topic'], aggfunc = np.mean)

# %%
df.Topic.unique()

# %%
df_heart = df[(df['Topic'] == 'Cardiovascular Disease')]
df_heart
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 255          2011     2011           KY              Kentucky
# 263          2014     2014           CO              Colorado
# 268          2013     2013           VT               Vermont
# 280          2014     2014           ME                 Maine
# 284          2011     2011           WI             Wisconsin
# 285          2014     2014           DC  District of Columbia
# 286          2015     2015           RI          Rhode Island
# 292          2013     2013           NM            New Mexico
# 306          2014     2014           UT                  Utah
# 322          2013     2013           LA             Louisiana
# 325          2011     2011           WA            Washington
# 338          2014     2014           HI                Hawaii
# 344          2012     2012           AR              Arkansas
# 367          2013     2013           HI                Hawaii
# ...

# %%
heart_list = df_heart['Question'].to_list()

# %%
heart_list
# Out:
# ['Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years',
#  'Mortality from heart failure',
#  'Hospitalization for acute myocardial infarction',
#  'Hospitalization for stroke',
#  'High cholesterol prevalence among adults aged >= 18 years',
#  'Hospitalization for stroke',
#  'Cholesterol screening among adults aged >= 18 years',
#  'Mortality from total cardiovascular diseases',
#  'Mortality from heart failure',
#  'Cholesterol screening among adults aged >= 18 years',
#  'Mortality from total cardiovascular diseases',
#  'Mortality from diseases of the heart',
#  'Mortality from heart failure',
#  'Mortality from diseases of the heart',
#  'Hospitalization for stroke',
#  'Hospitalization for stroke',
#  'Taking medicine for high blood pressure control among adults aged >= 18 years with high blood pressure',
#  'Mortality from total cardiovascular diseases',
#  'High cholesterol prevalence among adults aged >= 18 years',
# ...

# %%
 print(Counter(heart_list))
# Out:
# Counter({'Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years': 7488, 'Mortality from heart failure': 6135, 'Mortality from total cardiovascular diseases': 6135, 'Mortality from diseases of the heart': 6135, 'Mortality from cerebrovascular disease (stroke)': 6135, 'Mortality from coronary heart disease': 6135, 'Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke': 5220, 'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease': 5220, 'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease': 5220, 'Influenza vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease or stroke': 5220, 'Hospitalization for acute myocardial infarction': 2637, 'Hospitalization for stroke': 2637, 'High cholesterol prevalence among adults ag
# ...

# %%
#heart['DataValue'].replace("", np.nan, inplace=True) # replace empty string with np.nan
#df_heart['DataValue'].dropna(inplace=True) # drop nan values
#int_series = df_heart['DataValue'].astype(float) # change type

#calculated_series = int_series.apply(lambda x: x*(1/1.2))

#print(calculated_series)

# %%
 ##Here change the data type from object to float and assign to column 
df_heart['DataValue'] = df_heart['DataValue'].apply(pd.to_numeric, downcast='float', errors='coerce')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_heart.dtypes

# %%
df_heart.groupby(['YearEnd','Stratification1'])['DataValue'].mean()
# Out:
# YearEnd  Stratification1
# 2010     American Indian or Alaska Native      94.781412
#          Asian or Pacific Islander            149.417515
#          Black, non-Hispanic                  629.668141
#          Female                              1960.784524
#          Hispanic                             282.592411
#          Male                                1935.678892
#          Overall                             5752.984244
#          White, non-Hispanic                 3079.082278
# 2011     American Indian or Alaska Native     109.505647
#          Asian or Pacific Islander            142.592190
#          Black, non-Hispanic                  396.381294
#          Female                              1025.041902
#          Hispanic                             160.009955
#          Male                                 984.024076
#          Multiracial, non-Hispanic             49.904375
#          Other, non-Hispanic                   49.068932
# ...

# %%
df_heart.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'Latitute', 'longitude'],
#       dtype='object')

# %%
heart = df_heart.pivot_table(values =['YearEnd'], index =['LocationDesc', 'Stratification1','Question','DataValueUnit','DataValue'],  aggfunc = np.mean)

# %%
heart.head()
# Out:
#                                                                                                                               YearEnd
# LocationDesc Stratification1                  Question                                           DataValueUnit     DataValue
# Alabama      American Indian or Alaska Native Hospitalization for heart failure among Medicar... cases per 1,000   52.900002   2015.0
#                                                                                                                    54.259998   2012.0
#                                                                                                                    57.980000   2015.0
#                                                                                                                    60.470001   2012.0
#                                               Mortality from diseases of the heart               cases per 100,000 77.199997   2010.0

# %%
heart.head()

# %%
heart.columns
# Out:
# Index(['YearEnd'], dtype='object')

# %%
df_heart.groupby(['Question'])['DataValue'].mean().reset_index()
# Out:
#                                              Question    DataValue
# 0   Awareness of high blood pressure among adults ...    31.127993
# 1   Awareness of high blood pressure among women a...    15.289062
# 2   Cholesterol screening among adults aged >= 18 ...    77.539230
# 3   High cholesterol prevalence among adults aged ...    34.249160
# 4     Hospitalization for acute myocardial infarction  1568.146383
# 5   Hospitalization for heart failure among Medica...  3466.056522
# 6                          Hospitalization for stroke  1873.112336
# 7   Influenza vaccination among noninstitutionaliz...    40.733333
# 8   Influenza vaccination among noninstitutionaliz...    62.986365
# 9     Mortality from cerebrovascular disease (stroke)   591.807016
# 10              Mortality from coronary heart disease  1565.960428
# 11               Mortality from diseases of the heart  2405.788272
# 12                       Mortality from heart failure  1262.263578
# ...

# %%
df['DataValue'] = df['DataValue'].apply(pd.to_numeric, downcast='float', errors='coerce')

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'Latitute', 'longitude'],
#       dtype='object')

# %%
df.YearEnd.unique()
# Out:
# array([2015, 2012, 2014, 2011, 2013, 2010, 2016, 2001, 2007, 2008])

# %%
def disease_stats(year,state,disease):
    state_avg = df[(df.YearEnd== year)&(df.LocationAbbr== state)&(df.Topic==disease)].groupby(['Question','QuestionID','Stratification1','DataValueUnit','DataValueType'])['DataValue'].agg('mean').reset_index()
    return state_avg

# %%
disease_stats(2012,'NJ','Cancer')
# Out:
#                                              Question QuestionID  \
# 0   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 1   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 2   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 3   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 4   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 5   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 6   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 7   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 8   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 9   Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 10  Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 11  Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# 12  Fecal occult blood test, sigmoidoscopy, or col...     CAN3_0
# ...
